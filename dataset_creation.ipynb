# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/consommation-quotidienne-brute-regionale.csv",sep=";")

# %%
df_filter = df[df['code_insee_region']==32]  [['date_heure','date','heure','consommation_brute_electricite_rte']]

# %%
9*365*24*2
# Out:
# 157680

# %%
df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183983 entries, 16 to 2207789
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   date_heure                          183983 non-null  object
#  1   date                                183983 non-null  object
#  2   heure                               183983 non-null  object
#  3   consommation_brute_electricite_rte  183983 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 7.0+ MB

# %%
df_filter.to_csv("data/hdf_dataset.csv")

# %%
df
# Out:
#                         date_heure        date  heure  code_insee_region  \
# 0        2013-01-21T09:00:00+01:00  2013-01-21  09:00                 11
# 1        2013-01-21T09:00:00+01:00  2013-01-21  09:00                 24
# 2        2013-01-21T09:00:00+01:00  2013-01-21  09:00                 44
# 3        2013-01-21T09:00:00+01:00  2013-01-21  09:00                 76
# 4        2013-01-21T09:00:00+01:00  2013-01-21  09:00                 84
# ...                            ...         ...    ...                ...
# 2207791  2023-06-23T13:00:00+02:00  2023-06-23  13:00                 76
# 2207792  2023-06-23T13:30:00+02:00  2023-06-23  13:30                 24
# 2207793  2023-06-23T14:00:00+02:00  2023-06-23  14:00                 44
# 2207794  2023-06-23T14:00:00+02:00  2023-06-23  14:00                 52
# 2207795  2023-06-23T14:00:00+02:00  2023-06-23  14:00                 75
#
#                        region  consommation_brute_gaz_grtgaz    statut_grtgaz  \
# 0               Île-de-France                         4129.0        Définitif
# 1         Centre-Val de Loire                         4871.0        Définitif
# 2                   Grand Est                        17598.0        Définitif
# 3                   Occitanie                         2036.0        Définitif
# 4        Auvergne-Rhône-Alpes                        14353.0        Définitif
# ...                       ...                            ...              ...
# 2207791             Occitanie                          281.0  Meilleur Statut
# 2207792   Centre-Val de Loire                            NaN              NaN
# 2207793             Grand Est                         3552.0  Meilleur Statut
# 2207794      Pays de la Loire                          778.0  Meilleur Statut
# 2207795    Nouvelle-Aquitaine                          565.0  Meilleur Statut
#
#          consommation_brute_gaz_terega statut_terega  \
# 0                                  NaN           NaN
# 1                                  NaN           NaN
# 2                                  NaN           NaN
# 3                               4376.0     Définitif
# 4                                 94.0     Définitif
# ...                                ...           ...
# 2207791                          570.0     Définitif
# 2207792                            NaN           NaN
# 2207793                            NaN           NaN
# 2207794                            NaN           NaN
# 2207795                          746.0     Définitif
#
#          consommation_brute_gaz_totale  consommation_brute_electricite_rte  \
# 0                               4129.0                               13610
# 1                               4871.0                                3589
# 2                              17598.0                                7306
# 3                               6412.0                                6722
# 4                              14447.0                               10986
# ...                                ...                                 ...
# 2207791                          851.0                                4041
# 2207792                            NaN                                1761
# 2207793                         3552.0                                4548
# 2207794                          778.0                                2778
# 2207795                         1311.0                                4355
#
#         statut_rte  consommation_brute_totale
# 0        Définitif                    17739.0
# 1        Définitif                     8460.0
# 2        Définitif                    24904.0
# 3        Définitif                    13134.0
# 4        Définitif                    25433.0
# ...            ...                        ...
# 2207791  Consolidé                     4892.0
# 2207792  Consolidé                        NaN
# 2207793  Consolidé                     8100.0
# 2207794  Consolidé                     3556.0
# 2207795  Consolidé                     5666.0
#
# [2207796 rows x 13 columns]
